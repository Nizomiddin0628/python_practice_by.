# %% [markdown]
# <a href="https://colab.research.google.com/github/Nizomiddin0628/python_practice_by./blob/main/N%262_DIctionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
car_0 = {'model': 'audi rsq8', 'color':'black'}
print(car_0['model'])
print(car_0['color'])
# Out:
# audi rsq8
# black
